# %%
# %run data_to_csv.py
# Out:
# Data saved to C:\Users\User\Desktop\currency_project\data_file.csv

# %%
# %run top_10.py
# Out:
# TOP 10 bank divisions for currency exchange performance:
#                                               ОТДЕЛЕНИЕ  USD пок  USD прод  EUR пок  EUR прод  RUB пок  RUB прод Получено
# 564        Технобанк г. Минск, ул. Кульман, 21б  23:53    2.048     2.060    2.265     2.295    3.178     3.200   7491.0
# 0      Абсолютбанк г. Минск, пр. Независимости, 95 ...    2.047     2.057    2.266     2.282    3.176     3.205   7489.0
# 581    Франсабанк г.Минск, ул. Козлова, 2 (м-н "Оке...    2.046     2.054    2.265     2.278    3.175     3.200   7486.0
# 389      БСБ Банк г. Минск, ул. Шафарнянская 11  15:26    2.044     2.055    2.265     2.284    3.174     3.216   7483.0
# 400     БТА Банк г. Минск, ул. В. Хоружей, 20-2  08:53    2.043     2.056    2.270     2.285    3.165     3.200   7478.0
# 513    РРБ-Банк г Минск, пр-т Независимости, 58  15:25    2.045     2.057    2.265     2.285    3.165     3.195   7475.0
# ...

# %%
# %run chart.py
